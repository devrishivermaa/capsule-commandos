# %%
#!pip install torch torchvision timm

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import timm

# %%
num_classes = 10  
batch_size = 8 #32
learning_rate = 1e-4
epochs = 20
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(45),  
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)), 
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1), 
    
    transforms.RandomAutocontrast(p=0.2), 
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
         
])

transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
train_dataset = datasets.ImageFolder(root='Dataset/training', transform=transform_train)
val_dataset = datasets.ImageFolder(root='Dataset/validation', transform=transform_val)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) 

val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = timm.create_model('mvitv2_large', pretrained=True, num_classes=num_classes)
model = model.to(device)

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(pytorch_total_params)
# Out:
# 216851482

# %%
print(model)
# Out:
# MultiScaleVit(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 144, kernel_size=(7, 7), stride=(4, 4), padding=(3, 3))
#   )
#   (stages): ModuleList(
#     (0): MultiScaleVitStage(
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=144, out_features=432, bias=True)
#             (proj): Linear(in_features=144, out_features=144, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=144, out_features=576, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=576, out_features=144, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1): MultiScaleBlock(
#           (norm1): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=144, out_features=432, bias=True)
#             (proj): Linear(in_features=144, out_features=144, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(4, 4), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           (shortcut_proj_mlp): Linear(in_features=144, out_features=288, bias=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=144, out_features=576, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=576, out_features=288, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#     (1): MultiScaleVitStage(
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (shortcut_pool_attn): MaxPool2d(kernel_size=[3, 3], stride=(2, 2), padding=[1, 1], dilation=1, ceil_mode=False)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=288, out_features=864, bias=True)
#             (proj): Linear(in_features=288, out_features=288, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=288, out_features=1152, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1-4): 4 x MultiScaleBlock(
#           (norm1): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=288, out_features=864, bias=True)
#             (proj): Linear(in_features=288, out_features=288, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=288, out_features=1152, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1152, out_features=288, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (5): MultiScaleBlock(
#           (norm1): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=288, out_features=864, bias=True)
#             (proj): Linear(in_features=288, out_features=288, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           (shortcut_proj_mlp): Linear(in_features=288, out_features=576, bias=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=288, out_features=1152, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=1152, out_features=576, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#     (2): MultiScaleVitStage(
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (shortcut_pool_attn): MaxPool2d(kernel_size=[3, 3], stride=(2, 2), padding=[1, 1], dilation=1, ceil_mode=False)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=576, out_features=1728, bias=True)
#             (proj): Linear(in_features=576, out_features=576, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=576, out_features=2304, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1-34): 34 x MultiScaleBlock(
#           (norm1): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=576, out_features=1728, bias=True)
#             (proj): Linear(in_features=576, out_features=576, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=576, out_features=2304, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (35): MultiScaleBlock(
#           (norm1): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=576, out_features=1728, bias=True)
#             (proj): Linear(in_features=576, out_features=576, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((576,), eps=1e-06, elementwise_affine=True)
#           (shortcut_proj_mlp): Linear(in_features=576, out_features=1152, bias=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=576, out_features=2304, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=2304, out_features=1152, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#     (3): MultiScaleVitStage(
#       (blocks): ModuleList(
#         (0): MultiScaleBlock(
#           (norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#           (shortcut_pool_attn): MaxPool2d(kernel_size=[3, 3], stride=(2, 2), padding=[1, 1], dilation=1, ceil_mode=False)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#             (proj): Linear(in_features=1152, out_features=1152, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#         (1-3): 3 x MultiScaleBlock(
#           (norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#           (attn): MultiScaleAttention(
#             (qkv): Linear(in_features=1152, out_features=3456, bias=True)
#             (proj): Linear(in_features=1152, out_features=1152, bias=True)
#             (pool_q): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_q): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_k): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_k): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#             (pool_v): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=72, bias=False)
#             (norm_v): LayerNorm((72,), eps=1e-06, elementwise_affine=True)
#           )
#           (drop_path1): Identity()
#           (norm2): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=1152, out_features=4608, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (norm): Identity()
#             (fc2): Linear(in_features=4608, out_features=1152, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): Identity()
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#   (head): Sequential(
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=1152, out_features=10, bias=True)
#   )
# )

# %%
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# patch_embed.proj.weight True
# patch_embed.proj.bias True
# stages.0.blocks.0.norm1.weight True
# stages.0.blocks.0.norm1.bias True
# stages.0.blocks.0.attn.rel_pos_h True
# stages.0.blocks.0.attn.rel_pos_w True
# stages.0.blocks.0.attn.qkv.weight True
# stages.0.blocks.0.attn.qkv.bias True
# stages.0.blocks.0.attn.proj.weight True
# stages.0.blocks.0.attn.proj.bias True
# stages.0.blocks.0.attn.pool_q.weight True
# stages.0.blocks.0.attn.norm_q.weight True
# stages.0.blocks.0.attn.norm_q.bias True
# stages.0.blocks.0.attn.pool_k.weight True
# stages.0.blocks.0.attn.norm_k.weight True
# stages.0.blocks.0.attn.norm_k.bias True
# stages.0.blocks.0.attn.pool_v.weight True
# stages.0.blocks.0.attn.norm_v.weight True
# stages.0.blocks.0.attn.norm_v.bias True
# stages.0.blocks.0.norm2.weight True
# stages.0.blocks.0.norm2.bias True
# stages.0.blocks.0.mlp.fc1.weight True
# stages.0.blocks.0.mlp.fc1.bias True
# stages.0.blocks.0.mlp.fc2.weight True
# stages.0.blocks.0.mlp.fc2.bias True
# stages.0.blocks.1.norm1.weight True
# stages.0.blocks.1.norm1.bias True
# stages.0.blocks.1.attn.rel_pos_h True
# stages.0.blocks.1.attn.rel_pos_w True
# stages.0.blocks.1.attn.qkv.weight True
# stages.0.blocks.1.attn.qkv.bias True
# stages.0.blocks.1.attn.proj.weight True
# stages.0.blocks.1.attn.proj.bias True
# stages.0.blocks.1.attn.pool_q.weight True
# stages.0.blocks.1.attn.norm_q.weight True
# stages.0.blocks.1.attn.norm_q.bias True
# stages.0.blocks.1.attn.pool_k.weight True
# stages.0.blocks.1.attn.norm_k.weight True
# stages.0.blocks.1.attn.norm_k.bias True
# stages.0.blocks.1.attn.pool_v.weight True
# stages.0.blocks.1.attn.norm_v.weight True
# stages.0.blocks.1.attn.norm_v.bias True
# stages.0.blocks.1.norm2.weight True
# stages.0.blocks.1.norm2.bias True
# stages.0.blocks.1.shortcut_proj_mlp.weight True
# stages.0.blocks.1.shortcut_proj_mlp.bias True
# stages.0.blocks.1.mlp.fc1.weight True
# stages.0.blocks.1.mlp.fc1.bias True
# stages.0.blocks.1.mlp.fc2.weight True
# stages.0.blocks.1.mlp.fc2.bias True
# stages.1.blocks.0.norm1.weight True
# stages.1.blocks.0.norm1.bias True
# stages.1.blocks.0.attn.rel_pos_h True
# stages.1.blocks.0.attn.rel_pos_w True
# stages.1.blocks.0.attn.qkv.weight True
# stages.1.blocks.0.attn.qkv.bias True
# stages.1.blocks.0.attn.proj.weight True
# stages.1.blocks.0.attn.proj.bias True
# stages.1.blocks.0.attn.pool_q.weight True
# stages.1.blocks.0.attn.norm_q.weight True
# stages.1.blocks.0.attn.norm_q.bias True
# stages.1.blocks.0.attn.pool_k.weight True
# stages.1.blocks.0.attn.norm_k.weight True
# stages.1.blocks.0.attn.norm_k.bias True
# stages.1.blocks.0.attn.pool_v.weight True
# stages.1.blocks.0.attn.norm_v.weight True
# stages.1.blocks.0.attn.norm_v.bias True
# stages.1.blocks.0.norm2.weight True
# stages.1.blocks.0.norm2.bias True
# stages.1.blocks.0.mlp.fc1.weight True
# stages.1.blocks.0.mlp.fc1.bias True
# stages.1.blocks.0.mlp.fc2.weight True
# stages.1.blocks.0.mlp.fc2.bias True
# stages.1.blocks.1.norm1.weight True
# stages.1.blocks.1.norm1.bias True
# stages.1.blocks.1.attn.rel_pos_h True
# stages.1.blocks.1.attn.rel_pos_w True
# stages.1.blocks.1.attn.qkv.weight True
# stages.1.blocks.1.attn.qkv.bias True
# stages.1.blocks.1.attn.proj.weight True
# stages.1.blocks.1.attn.proj.bias True
# stages.1.blocks.1.attn.pool_q.weight True
# stages.1.blocks.1.attn.norm_q.weight True
# stages.1.blocks.1.attn.norm_q.bias True
# stages.1.blocks.1.attn.pool_k.weight True
# stages.1.blocks.1.attn.norm_k.weight True
# stages.1.blocks.1.attn.norm_k.bias True
# stages.1.blocks.1.attn.pool_v.weight True
# stages.1.blocks.1.attn.norm_v.weight True
# stages.1.blocks.1.attn.norm_v.bias True
# stages.1.blocks.1.norm2.weight True
# stages.1.blocks.1.norm2.bias True
# stages.1.blocks.1.mlp.fc1.weight True
# stages.1.blocks.1.mlp.fc1.bias True
# stages.1.blocks.1.mlp.fc2.weight True
# stages.1.blocks.1.mlp.fc2.bias True
# stages.1.blocks.2.norm1.weight True
# stages.1.blocks.2.norm1.bias True
# stages.1.blocks.2.attn.rel_pos_h True
# stages.1.blocks.2.attn.rel_pos_w True
# stages.1.blocks.2.attn.qkv.weight True
# stages.1.blocks.2.attn.qkv.bias True
# stages.1.blocks.2.attn.proj.weight True
# stages.1.blocks.2.attn.proj.bias True
# stages.1.blocks.2.attn.pool_q.weight True
# stages.1.blocks.2.attn.norm_q.weight True
# stages.1.blocks.2.attn.norm_q.bias True
# stages.1.blocks.2.attn.pool_k.weight True
# stages.1.blocks.2.attn.norm_k.weight True
# stages.1.blocks.2.attn.norm_k.bias True
# stages.1.blocks.2.attn.pool_v.weight True
# stages.1.blocks.2.attn.norm_v.weight True
# stages.1.blocks.2.attn.norm_v.bias True
# stages.1.blocks.2.norm2.weight True
# stages.1.blocks.2.norm2.bias True
# stages.1.blocks.2.mlp.fc1.weight True
# stages.1.blocks.2.mlp.fc1.bias True
# stages.1.blocks.2.mlp.fc2.weight True
# stages.1.blocks.2.mlp.fc2.bias True
# stages.1.blocks.3.norm1.weight True
# stages.1.blocks.3.norm1.bias True
# stages.1.blocks.3.attn.rel_pos_h True
# stages.1.blocks.3.attn.rel_pos_w True
# stages.1.blocks.3.attn.qkv.weight True
# stages.1.blocks.3.attn.qkv.bias True
# stages.1.blocks.3.attn.proj.weight True
# stages.1.blocks.3.attn.proj.bias True
# stages.1.blocks.3.attn.pool_q.weight True
# stages.1.blocks.3.attn.norm_q.weight True
# stages.1.blocks.3.attn.norm_q.bias True
# stages.1.blocks.3.attn.pool_k.weight True
# stages.1.blocks.3.attn.norm_k.weight True
# stages.1.blocks.3.attn.norm_k.bias True
# stages.1.blocks.3.attn.pool_v.weight True
# stages.1.blocks.3.attn.norm_v.weight True
# stages.1.blocks.3.attn.norm_v.bias True
# stages.1.blocks.3.norm2.weight True
# stages.1.blocks.3.norm2.bias True
# stages.1.blocks.3.mlp.fc1.weight True
# stages.1.blocks.3.mlp.fc1.bias True
# stages.1.blocks.3.mlp.fc2.weight True
# stages.1.blocks.3.mlp.fc2.bias True
# stages.1.blocks.4.norm1.weight True
# stages.1.blocks.4.norm1.bias True
# stages.1.blocks.4.attn.rel_pos_h True
# stages.1.blocks.4.attn.rel_pos_w True
# stages.1.blocks.4.attn.qkv.weight True
# stages.1.blocks.4.attn.qkv.bias True
# stages.1.blocks.4.attn.proj.weight True
# stages.1.blocks.4.attn.proj.bias True
# stages.1.blocks.4.attn.pool_q.weight True
# stages.1.blocks.4.attn.norm_q.weight True
# stages.1.blocks.4.attn.norm_q.bias True
# stages.1.blocks.4.attn.pool_k.weight True
# stages.1.blocks.4.attn.norm_k.weight True
# stages.1.blocks.4.attn.norm_k.bias True
# stages.1.blocks.4.attn.pool_v.weight True
# stages.1.blocks.4.attn.norm_v.weight True
# stages.1.blocks.4.attn.norm_v.bias True
# stages.1.blocks.4.norm2.weight True
# stages.1.blocks.4.norm2.bias True
# stages.1.blocks.4.mlp.fc1.weight True
# stages.1.blocks.4.mlp.fc1.bias True
# stages.1.blocks.4.mlp.fc2.weight True
# stages.1.blocks.4.mlp.fc2.bias True
# stages.1.blocks.5.norm1.weight True
# stages.1.blocks.5.norm1.bias True
# stages.1.blocks.5.attn.rel_pos_h True
# stages.1.blocks.5.attn.rel_pos_w True
# stages.1.blocks.5.attn.qkv.weight True
# stages.1.blocks.5.attn.qkv.bias True
# stages.1.blocks.5.attn.proj.weight True
# stages.1.blocks.5.attn.proj.bias True
# stages.1.blocks.5.attn.pool_q.weight True
# stages.1.blocks.5.attn.norm_q.weight True
# stages.1.blocks.5.attn.norm_q.bias True
# stages.1.blocks.5.attn.pool_k.weight True
# stages.1.blocks.5.attn.norm_k.weight True
# stages.1.blocks.5.attn.norm_k.bias True
# stages.1.blocks.5.attn.pool_v.weight True
# stages.1.blocks.5.attn.norm_v.weight True
# stages.1.blocks.5.attn.norm_v.bias True
# stages.1.blocks.5.norm2.weight True
# stages.1.blocks.5.norm2.bias True
# stages.1.blocks.5.shortcut_proj_mlp.weight True
# stages.1.blocks.5.shortcut_proj_mlp.bias True
# stages.1.blocks.5.mlp.fc1.weight True
# stages.1.blocks.5.mlp.fc1.bias True
# stages.1.blocks.5.mlp.fc2.weight True
# stages.1.blocks.5.mlp.fc2.bias True
# stages.2.blocks.0.norm1.weight True
# stages.2.blocks.0.norm1.bias True
# stages.2.blocks.0.attn.rel_pos_h True
# stages.2.blocks.0.attn.rel_pos_w True
# stages.2.blocks.0.attn.qkv.weight True
# stages.2.blocks.0.attn.qkv.bias True
# stages.2.blocks.0.attn.proj.weight True
# stages.2.blocks.0.attn.proj.bias True
# stages.2.blocks.0.attn.pool_q.weight True
# stages.2.blocks.0.attn.norm_q.weight True
# stages.2.blocks.0.attn.norm_q.bias True
# stages.2.blocks.0.attn.pool_k.weight True
# stages.2.blocks.0.attn.norm_k.weight True
# stages.2.blocks.0.attn.norm_k.bias True
# stages.2.blocks.0.attn.pool_v.weight True
# stages.2.blocks.0.attn.norm_v.weight True
# stages.2.blocks.0.attn.norm_v.bias True
# stages.2.blocks.0.norm2.weight True
# stages.2.blocks.0.norm2.bias True
# stages.2.blocks.0.mlp.fc1.weight True
# stages.2.blocks.0.mlp.fc1.bias True
# stages.2.blocks.0.mlp.fc2.weight True
# stages.2.blocks.0.mlp.fc2.bias True
# stages.2.blocks.1.norm1.weight True
# stages.2.blocks.1.norm1.bias True
# stages.2.blocks.1.attn.rel_pos_h True
# stages.2.blocks.1.attn.rel_pos_w True
# stages.2.blocks.1.attn.qkv.weight True
# stages.2.blocks.1.attn.qkv.bias True
# stages.2.blocks.1.attn.proj.weight True
# stages.2.blocks.1.attn.proj.bias True
# stages.2.blocks.1.attn.pool_q.weight True
# stages.2.blocks.1.attn.norm_q.weight True
# stages.2.blocks.1.attn.norm_q.bias True
# stages.2.blocks.1.attn.pool_k.weight True
# stages.2.blocks.1.attn.norm_k.weight True
# stages.2.blocks.1.attn.norm_k.bias True
# stages.2.blocks.1.attn.pool_v.weight True
# stages.2.blocks.1.attn.norm_v.weight True
# stages.2.blocks.1.attn.norm_v.bias True
# stages.2.blocks.1.norm2.weight True
# stages.2.blocks.1.norm2.bias True
# stages.2.blocks.1.mlp.fc1.weight True
# stages.2.blocks.1.mlp.fc1.bias True
# stages.2.blocks.1.mlp.fc2.weight True
# stages.2.blocks.1.mlp.fc2.bias True
# stages.2.blocks.2.norm1.weight True
# stages.2.blocks.2.norm1.bias True
# stages.2.blocks.2.attn.rel_pos_h True
# stages.2.blocks.2.attn.rel_pos_w True
# stages.2.blocks.2.attn.qkv.weight True
# stages.2.blocks.2.attn.qkv.bias True
# stages.2.blocks.2.attn.proj.weight True
# stages.2.blocks.2.attn.proj.bias True
# stages.2.blocks.2.attn.pool_q.weight True
# stages.2.blocks.2.attn.norm_q.weight True
# stages.2.blocks.2.attn.norm_q.bias True
# stages.2.blocks.2.attn.pool_k.weight True
# stages.2.blocks.2.attn.norm_k.weight True
# stages.2.blocks.2.attn.norm_k.bias True
# stages.2.blocks.2.attn.pool_v.weight True
# stages.2.blocks.2.attn.norm_v.weight True
# stages.2.blocks.2.attn.norm_v.bias True
# stages.2.blocks.2.norm2.weight True
# stages.2.blocks.2.norm2.bias True
# stages.2.blocks.2.mlp.fc1.weight True
# stages.2.blocks.2.mlp.fc1.bias True
# stages.2.blocks.2.mlp.fc2.weight True
# stages.2.blocks.2.mlp.fc2.bias True
# stages.2.blocks.3.norm1.weight True
# stages.2.blocks.3.norm1.bias True
# stages.2.blocks.3.attn.rel_pos_h True
# stages.2.blocks.3.attn.rel_pos_w True
# stages.2.blocks.3.attn.qkv.weight True
# stages.2.blocks.3.attn.qkv.bias True
# stages.2.blocks.3.attn.proj.weight True
# stages.2.blocks.3.attn.proj.bias True
# stages.2.blocks.3.attn.pool_q.weight True
# stages.2.blocks.3.attn.norm_q.weight True
# stages.2.blocks.3.attn.norm_q.bias True
# stages.2.blocks.3.attn.pool_k.weight True
# stages.2.blocks.3.attn.norm_k.weight True
# stages.2.blocks.3.attn.norm_k.bias True
# stages.2.blocks.3.attn.pool_v.weight True
# stages.2.blocks.3.attn.norm_v.weight True
# stages.2.blocks.3.attn.norm_v.bias True
# stages.2.blocks.3.norm2.weight True
# stages.2.blocks.3.norm2.bias True
# stages.2.blocks.3.mlp.fc1.weight True
# stages.2.blocks.3.mlp.fc1.bias True
# stages.2.blocks.3.mlp.fc2.weight True
# stages.2.blocks.3.mlp.fc2.bias True
# stages.2.blocks.4.norm1.weight True
# stages.2.blocks.4.norm1.bias True
# stages.2.blocks.4.attn.rel_pos_h True
# stages.2.blocks.4.attn.rel_pos_w True
# stages.2.blocks.4.attn.qkv.weight True
# stages.2.blocks.4.attn.qkv.bias True
# stages.2.blocks.4.attn.proj.weight True
# stages.2.blocks.4.attn.proj.bias True
# stages.2.blocks.4.attn.pool_q.weight True
# stages.2.blocks.4.attn.norm_q.weight True
# stages.2.blocks.4.attn.norm_q.bias True
# stages.2.blocks.4.attn.pool_k.weight True
# stages.2.blocks.4.attn.norm_k.weight True
# stages.2.blocks.4.attn.norm_k.bias True
# stages.2.blocks.4.attn.pool_v.weight True
# stages.2.blocks.4.attn.norm_v.weight True
# stages.2.blocks.4.attn.norm_v.bias True
# stages.2.blocks.4.norm2.weight True
# stages.2.blocks.4.norm2.bias True
# stages.2.blocks.4.mlp.fc1.weight True
# stages.2.blocks.4.mlp.fc1.bias True
# stages.2.blocks.4.mlp.fc2.weight True
# stages.2.blocks.4.mlp.fc2.bias True
# stages.2.blocks.5.norm1.weight True
# stages.2.blocks.5.norm1.bias True
# stages.2.blocks.5.attn.rel_pos_h True
# stages.2.blocks.5.attn.rel_pos_w True
# stages.2.blocks.5.attn.qkv.weight True
# stages.2.blocks.5.attn.qkv.bias True
# stages.2.blocks.5.attn.proj.weight True
# stages.2.blocks.5.attn.proj.bias True
# stages.2.blocks.5.attn.pool_q.weight True
# stages.2.blocks.5.attn.norm_q.weight True
# stages.2.blocks.5.attn.norm_q.bias True
# stages.2.blocks.5.attn.pool_k.weight True
# stages.2.blocks.5.attn.norm_k.weight True
# stages.2.blocks.5.attn.norm_k.bias True
# stages.2.blocks.5.attn.pool_v.weight True
# stages.2.blocks.5.attn.norm_v.weight True
# stages.2.blocks.5.attn.norm_v.bias True
# stages.2.blocks.5.norm2.weight True
# stages.2.blocks.5.norm2.bias True
# stages.2.blocks.5.mlp.fc1.weight True
# stages.2.blocks.5.mlp.fc1.bias True
# stages.2.blocks.5.mlp.fc2.weight True
# stages.2.blocks.5.mlp.fc2.bias True
# stages.2.blocks.6.norm1.weight True
# stages.2.blocks.6.norm1.bias True
# stages.2.blocks.6.attn.rel_pos_h True
# stages.2.blocks.6.attn.rel_pos_w True
# stages.2.blocks.6.attn.qkv.weight True
# stages.2.blocks.6.attn.qkv.bias True
# stages.2.blocks.6.attn.proj.weight True
# stages.2.blocks.6.attn.proj.bias True
# stages.2.blocks.6.attn.pool_q.weight True
# stages.2.blocks.6.attn.norm_q.weight True
# stages.2.blocks.6.attn.norm_q.bias True
# stages.2.blocks.6.attn.pool_k.weight True
# stages.2.blocks.6.attn.norm_k.weight True
# stages.2.blocks.6.attn.norm_k.bias True
# stages.2.blocks.6.attn.pool_v.weight True
# stages.2.blocks.6.attn.norm_v.weight True
# stages.2.blocks.6.attn.norm_v.bias True
# stages.2.blocks.6.norm2.weight True
# stages.2.blocks.6.norm2.bias True
# stages.2.blocks.6.mlp.fc1.weight True
# stages.2.blocks.6.mlp.fc1.bias True
# stages.2.blocks.6.mlp.fc2.weight True
# stages.2.blocks.6.mlp.fc2.bias True
# stages.2.blocks.7.norm1.weight True
# stages.2.blocks.7.norm1.bias True
# stages.2.blocks.7.attn.rel_pos_h True
# stages.2.blocks.7.attn.rel_pos_w True
# stages.2.blocks.7.attn.qkv.weight True
# stages.2.blocks.7.attn.qkv.bias True
# stages.2.blocks.7.attn.proj.weight True
# stages.2.blocks.7.attn.proj.bias True
# stages.2.blocks.7.attn.pool_q.weight True
# stages.2.blocks.7.attn.norm_q.weight True
# stages.2.blocks.7.attn.norm_q.bias True
# stages.2.blocks.7.attn.pool_k.weight True
# stages.2.blocks.7.attn.norm_k.weight True
# stages.2.blocks.7.attn.norm_k.bias True
# stages.2.blocks.7.attn.pool_v.weight True
# stages.2.blocks.7.attn.norm_v.weight True
# stages.2.blocks.7.attn.norm_v.bias True
# stages.2.blocks.7.norm2.weight True
# stages.2.blocks.7.norm2.bias True
# stages.2.blocks.7.mlp.fc1.weight True
# stages.2.blocks.7.mlp.fc1.bias True
# stages.2.blocks.7.mlp.fc2.weight True
# stages.2.blocks.7.mlp.fc2.bias True
# stages.2.blocks.8.norm1.weight True
# stages.2.blocks.8.norm1.bias True
# stages.2.blocks.8.attn.rel_pos_h True
# stages.2.blocks.8.attn.rel_pos_w True
# stages.2.blocks.8.attn.qkv.weight True
# stages.2.blocks.8.attn.qkv.bias True
# stages.2.blocks.8.attn.proj.weight True
# stages.2.blocks.8.attn.proj.bias True
# stages.2.blocks.8.attn.pool_q.weight True
# stages.2.blocks.8.attn.norm_q.weight True
# stages.2.blocks.8.attn.norm_q.bias True
# stages.2.blocks.8.attn.pool_k.weight True
# stages.2.blocks.8.attn.norm_k.weight True
# stages.2.blocks.8.attn.norm_k.bias True
# stages.2.blocks.8.attn.pool_v.weight True
# stages.2.blocks.8.attn.norm_v.weight True
# stages.2.blocks.8.attn.norm_v.bias True
# stages.2.blocks.8.norm2.weight True
# stages.2.blocks.8.norm2.bias True
# stages.2.blocks.8.mlp.fc1.weight True
# stages.2.blocks.8.mlp.fc1.bias True
# stages.2.blocks.8.mlp.fc2.weight True
# stages.2.blocks.8.mlp.fc2.bias True
# stages.2.blocks.9.norm1.weight True
# stages.2.blocks.9.norm1.bias True
# stages.2.blocks.9.attn.rel_pos_h True
# stages.2.blocks.9.attn.rel_pos_w True
# stages.2.blocks.9.attn.qkv.weight True
# stages.2.blocks.9.attn.qkv.bias True
# stages.2.blocks.9.attn.proj.weight True
# stages.2.blocks.9.attn.proj.bias True
# stages.2.blocks.9.attn.pool_q.weight True
# stages.2.blocks.9.attn.norm_q.weight True
# stages.2.blocks.9.attn.norm_q.bias True
# stages.2.blocks.9.attn.pool_k.weight True
# stages.2.blocks.9.attn.norm_k.weight True
# stages.2.blocks.9.attn.norm_k.bias True
# stages.2.blocks.9.attn.pool_v.weight True
# stages.2.blocks.9.attn.norm_v.weight True
# stages.2.blocks.9.attn.norm_v.bias True
# stages.2.blocks.9.norm2.weight True
# stages.2.blocks.9.norm2.bias True
# stages.2.blocks.9.mlp.fc1.weight True
# stages.2.blocks.9.mlp.fc1.bias True
# stages.2.blocks.9.mlp.fc2.weight True
# stages.2.blocks.9.mlp.fc2.bias True
# stages.2.blocks.10.norm1.weight True
# stages.2.blocks.10.norm1.bias True
# stages.2.blocks.10.attn.rel_pos_h True
# stages.2.blocks.10.attn.rel_pos_w True
# stages.2.blocks.10.attn.qkv.weight True
# stages.2.blocks.10.attn.qkv.bias True
# stages.2.blocks.10.attn.proj.weight True
# stages.2.blocks.10.attn.proj.bias True
# stages.2.blocks.10.attn.pool_q.weight True
# stages.2.blocks.10.attn.norm_q.weight True
# stages.2.blocks.10.attn.norm_q.bias True
# stages.2.blocks.10.attn.pool_k.weight True
# stages.2.blocks.10.attn.norm_k.weight True
# stages.2.blocks.10.attn.norm_k.bias True
# stages.2.blocks.10.attn.pool_v.weight True
# stages.2.blocks.10.attn.norm_v.weight True
# stages.2.blocks.10.attn.norm_v.bias True
# stages.2.blocks.10.norm2.weight True
# stages.2.blocks.10.norm2.bias True
# stages.2.blocks.10.mlp.fc1.weight True
# stages.2.blocks.10.mlp.fc1.bias True
# stages.2.blocks.10.mlp.fc2.weight True
# stages.2.blocks.10.mlp.fc2.bias True
# stages.2.blocks.11.norm1.weight True
# stages.2.blocks.11.norm1.bias True
# stages.2.blocks.11.attn.rel_pos_h True
# stages.2.blocks.11.attn.rel_pos_w True
# stages.2.blocks.11.attn.qkv.weight True
# stages.2.blocks.11.attn.qkv.bias True
# stages.2.blocks.11.attn.proj.weight True
# stages.2.blocks.11.attn.proj.bias True
# stages.2.blocks.11.attn.pool_q.weight True
# stages.2.blocks.11.attn.norm_q.weight True
# stages.2.blocks.11.attn.norm_q.bias True
# stages.2.blocks.11.attn.pool_k.weight True
# stages.2.blocks.11.attn.norm_k.weight True
# stages.2.blocks.11.attn.norm_k.bias True
# stages.2.blocks.11.attn.pool_v.weight True
# stages.2.blocks.11.attn.norm_v.weight True
# stages.2.blocks.11.attn.norm_v.bias True
# stages.2.blocks.11.norm2.weight True
# stages.2.blocks.11.norm2.bias True
# stages.2.blocks.11.mlp.fc1.weight True
# stages.2.blocks.11.mlp.fc1.bias True
# stages.2.blocks.11.mlp.fc2.weight True
# stages.2.blocks.11.mlp.fc2.bias True
# stages.2.blocks.12.norm1.weight True
# stages.2.blocks.12.norm1.bias True
# stages.2.blocks.12.attn.rel_pos_h True
# stages.2.blocks.12.attn.rel_pos_w True
# stages.2.blocks.12.attn.qkv.weight True
# stages.2.blocks.12.attn.qkv.bias True
# stages.2.blocks.12.attn.proj.weight True
# stages.2.blocks.12.attn.proj.bias True
# stages.2.blocks.12.attn.pool_q.weight True
# stages.2.blocks.12.attn.norm_q.weight True
# stages.2.blocks.12.attn.norm_q.bias True
# stages.2.blocks.12.attn.pool_k.weight True
# stages.2.blocks.12.attn.norm_k.weight True
# stages.2.blocks.12.attn.norm_k.bias True
# stages.2.blocks.12.attn.pool_v.weight True
# stages.2.blocks.12.attn.norm_v.weight True
# stages.2.blocks.12.attn.norm_v.bias True
# stages.2.blocks.12.norm2.weight True
# stages.2.blocks.12.norm2.bias True
# stages.2.blocks.12.mlp.fc1.weight True
# stages.2.blocks.12.mlp.fc1.bias True
# stages.2.blocks.12.mlp.fc2.weight True
# stages.2.blocks.12.mlp.fc2.bias True
# stages.2.blocks.13.norm1.weight True
# stages.2.blocks.13.norm1.bias True
# stages.2.blocks.13.attn.rel_pos_h True
# stages.2.blocks.13.attn.rel_pos_w True
# stages.2.blocks.13.attn.qkv.weight True
# stages.2.blocks.13.attn.qkv.bias True
# stages.2.blocks.13.attn.proj.weight True
# stages.2.blocks.13.attn.proj.bias True
# stages.2.blocks.13.attn.pool_q.weight True
# stages.2.blocks.13.attn.norm_q.weight True
# stages.2.blocks.13.attn.norm_q.bias True
# stages.2.blocks.13.attn.pool_k.weight True
# stages.2.blocks.13.attn.norm_k.weight True
# stages.2.blocks.13.attn.norm_k.bias True
# stages.2.blocks.13.attn.pool_v.weight True
# stages.2.blocks.13.attn.norm_v.weight True
# stages.2.blocks.13.attn.norm_v.bias True
# stages.2.blocks.13.norm2.weight True
# stages.2.blocks.13.norm2.bias True
# stages.2.blocks.13.mlp.fc1.weight True
# stages.2.blocks.13.mlp.fc1.bias True
# stages.2.blocks.13.mlp.fc2.weight True
# stages.2.blocks.13.mlp.fc2.bias True
# stages.2.blocks.14.norm1.weight True
# stages.2.blocks.14.norm1.bias True
# stages.2.blocks.14.attn.rel_pos_h True
# stages.2.blocks.14.attn.rel_pos_w True
# stages.2.blocks.14.attn.qkv.weight True
# stages.2.blocks.14.attn.qkv.bias True
# stages.2.blocks.14.attn.proj.weight True
# stages.2.blocks.14.attn.proj.bias True
# stages.2.blocks.14.attn.pool_q.weight True
# stages.2.blocks.14.attn.norm_q.weight True
# stages.2.blocks.14.attn.norm_q.bias True
# stages.2.blocks.14.attn.pool_k.weight True
# stages.2.blocks.14.attn.norm_k.weight True
# stages.2.blocks.14.attn.norm_k.bias True
# stages.2.blocks.14.attn.pool_v.weight True
# stages.2.blocks.14.attn.norm_v.weight True
# stages.2.blocks.14.attn.norm_v.bias True
# stages.2.blocks.14.norm2.weight True
# stages.2.blocks.14.norm2.bias True
# stages.2.blocks.14.mlp.fc1.weight True
# stages.2.blocks.14.mlp.fc1.bias True
# stages.2.blocks.14.mlp.fc2.weight True
# stages.2.blocks.14.mlp.fc2.bias True
# stages.2.blocks.15.norm1.weight True
# stages.2.blocks.15.norm1.bias True
# stages.2.blocks.15.attn.rel_pos_h True
# stages.2.blocks.15.attn.rel_pos_w True
# stages.2.blocks.15.attn.qkv.weight True
# stages.2.blocks.15.attn.qkv.bias True
# stages.2.blocks.15.attn.proj.weight True
# stages.2.blocks.15.attn.proj.bias True
# stages.2.blocks.15.attn.pool_q.weight True
# stages.2.blocks.15.attn.norm_q.weight True
# stages.2.blocks.15.attn.norm_q.bias True
# stages.2.blocks.15.attn.pool_k.weight True
# stages.2.blocks.15.attn.norm_k.weight True
# stages.2.blocks.15.attn.norm_k.bias True
# stages.2.blocks.15.attn.pool_v.weight True
# stages.2.blocks.15.attn.norm_v.weight True
# stages.2.blocks.15.attn.norm_v.bias True
# stages.2.blocks.15.norm2.weight True
# stages.2.blocks.15.norm2.bias True
# stages.2.blocks.15.mlp.fc1.weight True
# stages.2.blocks.15.mlp.fc1.bias True
# stages.2.blocks.15.mlp.fc2.weight True
# stages.2.blocks.15.mlp.fc2.bias True
# stages.2.blocks.16.norm1.weight True
# stages.2.blocks.16.norm1.bias True
# stages.2.blocks.16.attn.rel_pos_h True
# stages.2.blocks.16.attn.rel_pos_w True
# stages.2.blocks.16.attn.qkv.weight True
# stages.2.blocks.16.attn.qkv.bias True
# stages.2.blocks.16.attn.proj.weight True
# stages.2.blocks.16.attn.proj.bias True
# stages.2.blocks.16.attn.pool_q.weight True
# stages.2.blocks.16.attn.norm_q.weight True
# stages.2.blocks.16.attn.norm_q.bias True
# stages.2.blocks.16.attn.pool_k.weight True
# stages.2.blocks.16.attn.norm_k.weight True
# stages.2.blocks.16.attn.norm_k.bias True
# stages.2.blocks.16.attn.pool_v.weight True
# stages.2.blocks.16.attn.norm_v.weight True
# stages.2.blocks.16.attn.norm_v.bias True
# stages.2.blocks.16.norm2.weight True
# stages.2.blocks.16.norm2.bias True
# stages.2.blocks.16.mlp.fc1.weight True
# stages.2.blocks.16.mlp.fc1.bias True
# stages.2.blocks.16.mlp.fc2.weight True
# stages.2.blocks.16.mlp.fc2.bias True
# stages.2.blocks.17.norm1.weight True
# stages.2.blocks.17.norm1.bias True
# stages.2.blocks.17.attn.rel_pos_h True
# stages.2.blocks.17.attn.rel_pos_w True
# stages.2.blocks.17.attn.qkv.weight True
# stages.2.blocks.17.attn.qkv.bias True
# stages.2.blocks.17.attn.proj.weight True
# stages.2.blocks.17.attn.proj.bias True
# stages.2.blocks.17.attn.pool_q.weight True
# stages.2.blocks.17.attn.norm_q.weight True
# stages.2.blocks.17.attn.norm_q.bias True
# stages.2.blocks.17.attn.pool_k.weight True
# stages.2.blocks.17.attn.norm_k.weight True
# stages.2.blocks.17.attn.norm_k.bias True
# stages.2.blocks.17.attn.pool_v.weight True
# stages.2.blocks.17.attn.norm_v.weight True
# stages.2.blocks.17.attn.norm_v.bias True
# stages.2.blocks.17.norm2.weight True
# stages.2.blocks.17.norm2.bias True
# stages.2.blocks.17.mlp.fc1.weight True
# stages.2.blocks.17.mlp.fc1.bias True
# stages.2.blocks.17.mlp.fc2.weight True
# stages.2.blocks.17.mlp.fc2.bias True
# stages.2.blocks.18.norm1.weight True
# stages.2.blocks.18.norm1.bias True
# stages.2.blocks.18.attn.rel_pos_h True
# stages.2.blocks.18.attn.rel_pos_w True
# stages.2.blocks.18.attn.qkv.weight True
# stages.2.blocks.18.attn.qkv.bias True
# stages.2.blocks.18.attn.proj.weight True
# stages.2.blocks.18.attn.proj.bias True
# stages.2.blocks.18.attn.pool_q.weight True
# stages.2.blocks.18.attn.norm_q.weight True
# stages.2.blocks.18.attn.norm_q.bias True
# stages.2.blocks.18.attn.pool_k.weight True
# stages.2.blocks.18.attn.norm_k.weight True
# stages.2.blocks.18.attn.norm_k.bias True
# stages.2.blocks.18.attn.pool_v.weight True
# stages.2.blocks.18.attn.norm_v.weight True
# stages.2.blocks.18.attn.norm_v.bias True
# stages.2.blocks.18.norm2.weight True
# stages.2.blocks.18.norm2.bias True
# stages.2.blocks.18.mlp.fc1.weight True
# stages.2.blocks.18.mlp.fc1.bias True
# stages.2.blocks.18.mlp.fc2.weight True
# stages.2.blocks.18.mlp.fc2.bias True
# stages.2.blocks.19.norm1.weight True
# stages.2.blocks.19.norm1.bias True
# stages.2.blocks.19.attn.rel_pos_h True
# stages.2.blocks.19.attn.rel_pos_w True
# stages.2.blocks.19.attn.qkv.weight True
# stages.2.blocks.19.attn.qkv.bias True
# stages.2.blocks.19.attn.proj.weight True
# stages.2.blocks.19.attn.proj.bias True
# stages.2.blocks.19.attn.pool_q.weight True
# stages.2.blocks.19.attn.norm_q.weight True
# stages.2.blocks.19.attn.norm_q.bias True
# stages.2.blocks.19.attn.pool_k.weight True
# stages.2.blocks.19.attn.norm_k.weight True
# stages.2.blocks.19.attn.norm_k.bias True
# stages.2.blocks.19.attn.pool_v.weight True
# stages.2.blocks.19.attn.norm_v.weight True
# stages.2.blocks.19.attn.norm_v.bias True
# stages.2.blocks.19.norm2.weight True
# stages.2.blocks.19.norm2.bias True
# stages.2.blocks.19.mlp.fc1.weight True
# stages.2.blocks.19.mlp.fc1.bias True
# stages.2.blocks.19.mlp.fc2.weight True
# stages.2.blocks.19.mlp.fc2.bias True
# stages.2.blocks.20.norm1.weight True
# stages.2.blocks.20.norm1.bias True
# stages.2.blocks.20.attn.rel_pos_h True
# stages.2.blocks.20.attn.rel_pos_w True
# stages.2.blocks.20.attn.qkv.weight True
# stages.2.blocks.20.attn.qkv.bias True
# stages.2.blocks.20.attn.proj.weight True
# stages.2.blocks.20.attn.proj.bias True
# stages.2.blocks.20.attn.pool_q.weight True
# stages.2.blocks.20.attn.norm_q.weight True
# stages.2.blocks.20.attn.norm_q.bias True
# stages.2.blocks.20.attn.pool_k.weight True
# stages.2.blocks.20.attn.norm_k.weight True
# stages.2.blocks.20.attn.norm_k.bias True
# stages.2.blocks.20.attn.pool_v.weight True
# stages.2.blocks.20.attn.norm_v.weight True
# stages.2.blocks.20.attn.norm_v.bias True
# stages.2.blocks.20.norm2.weight True
# stages.2.blocks.20.norm2.bias True
# stages.2.blocks.20.mlp.fc1.weight True
# stages.2.blocks.20.mlp.fc1.bias True
# stages.2.blocks.20.mlp.fc2.weight True
# stages.2.blocks.20.mlp.fc2.bias True
# stages.2.blocks.21.norm1.weight True
# stages.2.blocks.21.norm1.bias True
# stages.2.blocks.21.attn.rel_pos_h True
# stages.2.blocks.21.attn.rel_pos_w True
# stages.2.blocks.21.attn.qkv.weight True
# stages.2.blocks.21.attn.qkv.bias True
# stages.2.blocks.21.attn.proj.weight True
# stages.2.blocks.21.attn.proj.bias True
# stages.2.blocks.21.attn.pool_q.weight True
# stages.2.blocks.21.attn.norm_q.weight True
# stages.2.blocks.21.attn.norm_q.bias True
# stages.2.blocks.21.attn.pool_k.weight True
# stages.2.blocks.21.attn.norm_k.weight True
# stages.2.blocks.21.attn.norm_k.bias True
# stages.2.blocks.21.attn.pool_v.weight True
# stages.2.blocks.21.attn.norm_v.weight True
# stages.2.blocks.21.attn.norm_v.bias True
# stages.2.blocks.21.norm2.weight True
# stages.2.blocks.21.norm2.bias True
# stages.2.blocks.21.mlp.fc1.weight True
# stages.2.blocks.21.mlp.fc1.bias True
# stages.2.blocks.21.mlp.fc2.weight True
# stages.2.blocks.21.mlp.fc2.bias True
# stages.2.blocks.22.norm1.weight True
# stages.2.blocks.22.norm1.bias True
# stages.2.blocks.22.attn.rel_pos_h True
# stages.2.blocks.22.attn.rel_pos_w True
# stages.2.blocks.22.attn.qkv.weight True
# stages.2.blocks.22.attn.qkv.bias True
# stages.2.blocks.22.attn.proj.weight True
# stages.2.blocks.22.attn.proj.bias True
# stages.2.blocks.22.attn.pool_q.weight True
# stages.2.blocks.22.attn.norm_q.weight True
# stages.2.blocks.22.attn.norm_q.bias True
# stages.2.blocks.22.attn.pool_k.weight True
# stages.2.blocks.22.attn.norm_k.weight True
# stages.2.blocks.22.attn.norm_k.bias True
# stages.2.blocks.22.attn.pool_v.weight True
# stages.2.blocks.22.attn.norm_v.weight True
# stages.2.blocks.22.attn.norm_v.bias True
# stages.2.blocks.22.norm2.weight True
# stages.2.blocks.22.norm2.bias True
# stages.2.blocks.22.mlp.fc1.weight True
# stages.2.blocks.22.mlp.fc1.bias True
# stages.2.blocks.22.mlp.fc2.weight True
# stages.2.blocks.22.mlp.fc2.bias True
# stages.2.blocks.23.norm1.weight True
# stages.2.blocks.23.norm1.bias True
# stages.2.blocks.23.attn.rel_pos_h True
# stages.2.blocks.23.attn.rel_pos_w True
# stages.2.blocks.23.attn.qkv.weight True
# stages.2.blocks.23.attn.qkv.bias True
# stages.2.blocks.23.attn.proj.weight True
# stages.2.blocks.23.attn.proj.bias True
# stages.2.blocks.23.attn.pool_q.weight True
# stages.2.blocks.23.attn.norm_q.weight True
# stages.2.blocks.23.attn.norm_q.bias True
# stages.2.blocks.23.attn.pool_k.weight True
# stages.2.blocks.23.attn.norm_k.weight True
# stages.2.blocks.23.attn.norm_k.bias True
# stages.2.blocks.23.attn.pool_v.weight True
# stages.2.blocks.23.attn.norm_v.weight True
# stages.2.blocks.23.attn.norm_v.bias True
# stages.2.blocks.23.norm2.weight True
# stages.2.blocks.23.norm2.bias True
# stages.2.blocks.23.mlp.fc1.weight True
# stages.2.blocks.23.mlp.fc1.bias True
# stages.2.blocks.23.mlp.fc2.weight True
# stages.2.blocks.23.mlp.fc2.bias True
# stages.2.blocks.24.norm1.weight True
# stages.2.blocks.24.norm1.bias True
# stages.2.blocks.24.attn.rel_pos_h True
# stages.2.blocks.24.attn.rel_pos_w True
# stages.2.blocks.24.attn.qkv.weight True
# stages.2.blocks.24.attn.qkv.bias True
# stages.2.blocks.24.attn.proj.weight True
# stages.2.blocks.24.attn.proj.bias True
# stages.2.blocks.24.attn.pool_q.weight True
# stages.2.blocks.24.attn.norm_q.weight True
# stages.2.blocks.24.attn.norm_q.bias True
# stages.2.blocks.24.attn.pool_k.weight True
# stages.2.blocks.24.attn.norm_k.weight True
# stages.2.blocks.24.attn.norm_k.bias True
# stages.2.blocks.24.attn.pool_v.weight True
# stages.2.blocks.24.attn.norm_v.weight True
# stages.2.blocks.24.attn.norm_v.bias True
# stages.2.blocks.24.norm2.weight True
# stages.2.blocks.24.norm2.bias True
# stages.2.blocks.24.mlp.fc1.weight True
# stages.2.blocks.24.mlp.fc1.bias True
# stages.2.blocks.24.mlp.fc2.weight True
# stages.2.blocks.24.mlp.fc2.bias True
# stages.2.blocks.25.norm1.weight True
# stages.2.blocks.25.norm1.bias True
# stages.2.blocks.25.attn.rel_pos_h True
# stages.2.blocks.25.attn.rel_pos_w True
# stages.2.blocks.25.attn.qkv.weight True
# stages.2.blocks.25.attn.qkv.bias True
# stages.2.blocks.25.attn.proj.weight True
# stages.2.blocks.25.attn.proj.bias True
# stages.2.blocks.25.attn.pool_q.weight True
# stages.2.blocks.25.attn.norm_q.weight True
# stages.2.blocks.25.attn.norm_q.bias True
# stages.2.blocks.25.attn.pool_k.weight True
# stages.2.blocks.25.attn.norm_k.weight True
# stages.2.blocks.25.attn.norm_k.bias True
# stages.2.blocks.25.attn.pool_v.weight True
# stages.2.blocks.25.attn.norm_v.weight True
# stages.2.blocks.25.attn.norm_v.bias True
# stages.2.blocks.25.norm2.weight True
# stages.2.blocks.25.norm2.bias True
# stages.2.blocks.25.mlp.fc1.weight True
# stages.2.blocks.25.mlp.fc1.bias True
# stages.2.blocks.25.mlp.fc2.weight True
# stages.2.blocks.25.mlp.fc2.bias True
# stages.2.blocks.26.norm1.weight True
# stages.2.blocks.26.norm1.bias True
# stages.2.blocks.26.attn.rel_pos_h True
# stages.2.blocks.26.attn.rel_pos_w True
# stages.2.blocks.26.attn.qkv.weight True
# stages.2.blocks.26.attn.qkv.bias True
# stages.2.blocks.26.attn.proj.weight True
# stages.2.blocks.26.attn.proj.bias True
# stages.2.blocks.26.attn.pool_q.weight True
# stages.2.blocks.26.attn.norm_q.weight True
# stages.2.blocks.26.attn.norm_q.bias True
# stages.2.blocks.26.attn.pool_k.weight True
# stages.2.blocks.26.attn.norm_k.weight True
# stages.2.blocks.26.attn.norm_k.bias True
# stages.2.blocks.26.attn.pool_v.weight True
# stages.2.blocks.26.attn.norm_v.weight True
# stages.2.blocks.26.attn.norm_v.bias True
# stages.2.blocks.26.norm2.weight True
# stages.2.blocks.26.norm2.bias True
# stages.2.blocks.26.mlp.fc1.weight True
# stages.2.blocks.26.mlp.fc1.bias True
# stages.2.blocks.26.mlp.fc2.weight True
# stages.2.blocks.26.mlp.fc2.bias True
# stages.2.blocks.27.norm1.weight True
# stages.2.blocks.27.norm1.bias True
# stages.2.blocks.27.attn.rel_pos_h True
# stages.2.blocks.27.attn.rel_pos_w True
# stages.2.blocks.27.attn.qkv.weight True
# stages.2.blocks.27.attn.qkv.bias True
# stages.2.blocks.27.attn.proj.weight True
# stages.2.blocks.27.attn.proj.bias True
# stages.2.blocks.27.attn.pool_q.weight True
# stages.2.blocks.27.attn.norm_q.weight True
# stages.2.blocks.27.attn.norm_q.bias True
# stages.2.blocks.27.attn.pool_k.weight True
# stages.2.blocks.27.attn.norm_k.weight True
# stages.2.blocks.27.attn.norm_k.bias True
# stages.2.blocks.27.attn.pool_v.weight True
# stages.2.blocks.27.attn.norm_v.weight True
# stages.2.blocks.27.attn.norm_v.bias True
# stages.2.blocks.27.norm2.weight True
# stages.2.blocks.27.norm2.bias True
# stages.2.blocks.27.mlp.fc1.weight True
# stages.2.blocks.27.mlp.fc1.bias True
# stages.2.blocks.27.mlp.fc2.weight True
# stages.2.blocks.27.mlp.fc2.bias True
# stages.2.blocks.28.norm1.weight True
# stages.2.blocks.28.norm1.bias True
# stages.2.blocks.28.attn.rel_pos_h True
# stages.2.blocks.28.attn.rel_pos_w True
# stages.2.blocks.28.attn.qkv.weight True
# stages.2.blocks.28.attn.qkv.bias True
# stages.2.blocks.28.attn.proj.weight True
# stages.2.blocks.28.attn.proj.bias True
# stages.2.blocks.28.attn.pool_q.weight True
# stages.2.blocks.28.attn.norm_q.weight True
# stages.2.blocks.28.attn.norm_q.bias True
# stages.2.blocks.28.attn.pool_k.weight True
# stages.2.blocks.28.attn.norm_k.weight True
# stages.2.blocks.28.attn.norm_k.bias True
# stages.2.blocks.28.attn.pool_v.weight True
# stages.2.blocks.28.attn.norm_v.weight True
# stages.2.blocks.28.attn.norm_v.bias True
# stages.2.blocks.28.norm2.weight True
# stages.2.blocks.28.norm2.bias True
# stages.2.blocks.28.mlp.fc1.weight True
# stages.2.blocks.28.mlp.fc1.bias True
# stages.2.blocks.28.mlp.fc2.weight True
# stages.2.blocks.28.mlp.fc2.bias True
# stages.2.blocks.29.norm1.weight True
# stages.2.blocks.29.norm1.bias True
# stages.2.blocks.29.attn.rel_pos_h True
# stages.2.blocks.29.attn.rel_pos_w True
# stages.2.blocks.29.attn.qkv.weight True
# stages.2.blocks.29.attn.qkv.bias True
# stages.2.blocks.29.attn.proj.weight True
# stages.2.blocks.29.attn.proj.bias True
# stages.2.blocks.29.attn.pool_q.weight True
# stages.2.blocks.29.attn.norm_q.weight True
# stages.2.blocks.29.attn.norm_q.bias True
# stages.2.blocks.29.attn.pool_k.weight True
# stages.2.blocks.29.attn.norm_k.weight True
# stages.2.blocks.29.attn.norm_k.bias True
# stages.2.blocks.29.attn.pool_v.weight True
# stages.2.blocks.29.attn.norm_v.weight True
# stages.2.blocks.29.attn.norm_v.bias True
# stages.2.blocks.29.norm2.weight True
# stages.2.blocks.29.norm2.bias True
# stages.2.blocks.29.mlp.fc1.weight True
# stages.2.blocks.29.mlp.fc1.bias True
# stages.2.blocks.29.mlp.fc2.weight True
# stages.2.blocks.29.mlp.fc2.bias True
# stages.2.blocks.30.norm1.weight True
# stages.2.blocks.30.norm1.bias True
# stages.2.blocks.30.attn.rel_pos_h True
# stages.2.blocks.30.attn.rel_pos_w True
# stages.2.blocks.30.attn.qkv.weight True
# stages.2.blocks.30.attn.qkv.bias True
# stages.2.blocks.30.attn.proj.weight True
# stages.2.blocks.30.attn.proj.bias True
# stages.2.blocks.30.attn.pool_q.weight True
# stages.2.blocks.30.attn.norm_q.weight True
# stages.2.blocks.30.attn.norm_q.bias True
# stages.2.blocks.30.attn.pool_k.weight True
# stages.2.blocks.30.attn.norm_k.weight True
# stages.2.blocks.30.attn.norm_k.bias True
# stages.2.blocks.30.attn.pool_v.weight True
# stages.2.blocks.30.attn.norm_v.weight True
# stages.2.blocks.30.attn.norm_v.bias True
# stages.2.blocks.30.norm2.weight True
# stages.2.blocks.30.norm2.bias True
# stages.2.blocks.30.mlp.fc1.weight True
# stages.2.blocks.30.mlp.fc1.bias True
# stages.2.blocks.30.mlp.fc2.weight True
# stages.2.blocks.30.mlp.fc2.bias True
# stages.2.blocks.31.norm1.weight True
# stages.2.blocks.31.norm1.bias True
# stages.2.blocks.31.attn.rel_pos_h True
# stages.2.blocks.31.attn.rel_pos_w True
# stages.2.blocks.31.attn.qkv.weight True
# stages.2.blocks.31.attn.qkv.bias True
# stages.2.blocks.31.attn.proj.weight True
# stages.2.blocks.31.attn.proj.bias True
# stages.2.blocks.31.attn.pool_q.weight True
# stages.2.blocks.31.attn.norm_q.weight True
# stages.2.blocks.31.attn.norm_q.bias True
# stages.2.blocks.31.attn.pool_k.weight True
# stages.2.blocks.31.attn.norm_k.weight True
# stages.2.blocks.31.attn.norm_k.bias True
# stages.2.blocks.31.attn.pool_v.weight True
# stages.2.blocks.31.attn.norm_v.weight True
# stages.2.blocks.31.attn.norm_v.bias True
# stages.2.blocks.31.norm2.weight True
# stages.2.blocks.31.norm2.bias True
# stages.2.blocks.31.mlp.fc1.weight True
# stages.2.blocks.31.mlp.fc1.bias True
# stages.2.blocks.31.mlp.fc2.weight True
# stages.2.blocks.31.mlp.fc2.bias True
# stages.2.blocks.32.norm1.weight True
# stages.2.blocks.32.norm1.bias True
# stages.2.blocks.32.attn.rel_pos_h True
# stages.2.blocks.32.attn.rel_pos_w True
# stages.2.blocks.32.attn.qkv.weight True
# stages.2.blocks.32.attn.qkv.bias True
# stages.2.blocks.32.attn.proj.weight True
# stages.2.blocks.32.attn.proj.bias True
# stages.2.blocks.32.attn.pool_q.weight True
# stages.2.blocks.32.attn.norm_q.weight True
# stages.2.blocks.32.attn.norm_q.bias True
# stages.2.blocks.32.attn.pool_k.weight True
# stages.2.blocks.32.attn.norm_k.weight True
# stages.2.blocks.32.attn.norm_k.bias True
# stages.2.blocks.32.attn.pool_v.weight True
# stages.2.blocks.32.attn.norm_v.weight True
# stages.2.blocks.32.attn.norm_v.bias True
# stages.2.blocks.32.norm2.weight True
# stages.2.blocks.32.norm2.bias True
# stages.2.blocks.32.mlp.fc1.weight True
# stages.2.blocks.32.mlp.fc1.bias True
# stages.2.blocks.32.mlp.fc2.weight True
# stages.2.blocks.32.mlp.fc2.bias True
# stages.2.blocks.33.norm1.weight True
# stages.2.blocks.33.norm1.bias True
# stages.2.blocks.33.attn.rel_pos_h True
# stages.2.blocks.33.attn.rel_pos_w True
# stages.2.blocks.33.attn.qkv.weight True
# stages.2.blocks.33.attn.qkv.bias True
# stages.2.blocks.33.attn.proj.weight True
# stages.2.blocks.33.attn.proj.bias True
# stages.2.blocks.33.attn.pool_q.weight True
# stages.2.blocks.33.attn.norm_q.weight True
# stages.2.blocks.33.attn.norm_q.bias True
# stages.2.blocks.33.attn.pool_k.weight True
# stages.2.blocks.33.attn.norm_k.weight True
# stages.2.blocks.33.attn.norm_k.bias True
# stages.2.blocks.33.attn.pool_v.weight True
# stages.2.blocks.33.attn.norm_v.weight True
# stages.2.blocks.33.attn.norm_v.bias True
# stages.2.blocks.33.norm2.weight True
# stages.2.blocks.33.norm2.bias True
# stages.2.blocks.33.mlp.fc1.weight True
# stages.2.blocks.33.mlp.fc1.bias True
# stages.2.blocks.33.mlp.fc2.weight True
# stages.2.blocks.33.mlp.fc2.bias True
# stages.2.blocks.34.norm1.weight True
# stages.2.blocks.34.norm1.bias True
# stages.2.blocks.34.attn.rel_pos_h True
# stages.2.blocks.34.attn.rel_pos_w True
# stages.2.blocks.34.attn.qkv.weight True
# stages.2.blocks.34.attn.qkv.bias True
# stages.2.blocks.34.attn.proj.weight True
# stages.2.blocks.34.attn.proj.bias True
# stages.2.blocks.34.attn.pool_q.weight True
# stages.2.blocks.34.attn.norm_q.weight True
# stages.2.blocks.34.attn.norm_q.bias True
# stages.2.blocks.34.attn.pool_k.weight True
# stages.2.blocks.34.attn.norm_k.weight True
# stages.2.blocks.34.attn.norm_k.bias True
# stages.2.blocks.34.attn.pool_v.weight True
# stages.2.blocks.34.attn.norm_v.weight True
# stages.2.blocks.34.attn.norm_v.bias True
# stages.2.blocks.34.norm2.weight True
# stages.2.blocks.34.norm2.bias True
# stages.2.blocks.34.mlp.fc1.weight True
# stages.2.blocks.34.mlp.fc1.bias True
# stages.2.blocks.34.mlp.fc2.weight True
# stages.2.blocks.34.mlp.fc2.bias True
# stages.2.blocks.35.norm1.weight True
# stages.2.blocks.35.norm1.bias True
# stages.2.blocks.35.attn.rel_pos_h True
# stages.2.blocks.35.attn.rel_pos_w True
# stages.2.blocks.35.attn.qkv.weight True
# stages.2.blocks.35.attn.qkv.bias True
# stages.2.blocks.35.attn.proj.weight True
# stages.2.blocks.35.attn.proj.bias True
# stages.2.blocks.35.attn.pool_q.weight True
# stages.2.blocks.35.attn.norm_q.weight True
# stages.2.blocks.35.attn.norm_q.bias True
# stages.2.blocks.35.attn.pool_k.weight True
# stages.2.blocks.35.attn.norm_k.weight True
# stages.2.blocks.35.attn.norm_k.bias True
# stages.2.blocks.35.attn.pool_v.weight True
# stages.2.blocks.35.attn.norm_v.weight True
# stages.2.blocks.35.attn.norm_v.bias True
# stages.2.blocks.35.norm2.weight True
# stages.2.blocks.35.norm2.bias True
# stages.2.blocks.35.shortcut_proj_mlp.weight True
# stages.2.blocks.35.shortcut_proj_mlp.bias True
# stages.2.blocks.35.mlp.fc1.weight True
# stages.2.blocks.35.mlp.fc1.bias True
# stages.2.blocks.35.mlp.fc2.weight True
# stages.2.blocks.35.mlp.fc2.bias True
# stages.3.blocks.0.norm1.weight True
# stages.3.blocks.0.norm1.bias True
# stages.3.blocks.0.attn.rel_pos_h True
# stages.3.blocks.0.attn.rel_pos_w True
# stages.3.blocks.0.attn.qkv.weight True
# stages.3.blocks.0.attn.qkv.bias True
# stages.3.blocks.0.attn.proj.weight True
# stages.3.blocks.0.attn.proj.bias True
# stages.3.blocks.0.attn.pool_q.weight True
# stages.3.blocks.0.attn.norm_q.weight True
# stages.3.blocks.0.attn.norm_q.bias True
# stages.3.blocks.0.attn.pool_k.weight True
# stages.3.blocks.0.attn.norm_k.weight True
# stages.3.blocks.0.attn.norm_k.bias True
# stages.3.blocks.0.attn.pool_v.weight True
# stages.3.blocks.0.attn.norm_v.weight True
# stages.3.blocks.0.attn.norm_v.bias True
# stages.3.blocks.0.norm2.weight True
# stages.3.blocks.0.norm2.bias True
# stages.3.blocks.0.mlp.fc1.weight True
# stages.3.blocks.0.mlp.fc1.bias True
# stages.3.blocks.0.mlp.fc2.weight True
# stages.3.blocks.0.mlp.fc2.bias True
# stages.3.blocks.1.norm1.weight True
# stages.3.blocks.1.norm1.bias True
# stages.3.blocks.1.attn.rel_pos_h True
# stages.3.blocks.1.attn.rel_pos_w True
# stages.3.blocks.1.attn.qkv.weight True
# stages.3.blocks.1.attn.qkv.bias True
# stages.3.blocks.1.attn.proj.weight True
# stages.3.blocks.1.attn.proj.bias True
# stages.3.blocks.1.attn.pool_q.weight True
# stages.3.blocks.1.attn.norm_q.weight True
# stages.3.blocks.1.attn.norm_q.bias True
# stages.3.blocks.1.attn.pool_k.weight True
# stages.3.blocks.1.attn.norm_k.weight True
# stages.3.blocks.1.attn.norm_k.bias True
# stages.3.blocks.1.attn.pool_v.weight True
# stages.3.blocks.1.attn.norm_v.weight True
# stages.3.blocks.1.attn.norm_v.bias True
# stages.3.blocks.1.norm2.weight True
# stages.3.blocks.1.norm2.bias True
# stages.3.blocks.1.mlp.fc1.weight True
# stages.3.blocks.1.mlp.fc1.bias True
# stages.3.blocks.1.mlp.fc2.weight True
# stages.3.blocks.1.mlp.fc2.bias True
# stages.3.blocks.2.norm1.weight True
# stages.3.blocks.2.norm1.bias True
# stages.3.blocks.2.attn.rel_pos_h True
# stages.3.blocks.2.attn.rel_pos_w True
# stages.3.blocks.2.attn.qkv.weight True
# stages.3.blocks.2.attn.qkv.bias True
# stages.3.blocks.2.attn.proj.weight True
# stages.3.blocks.2.attn.proj.bias True
# stages.3.blocks.2.attn.pool_q.weight True
# stages.3.blocks.2.attn.norm_q.weight True
# stages.3.blocks.2.attn.norm_q.bias True
# stages.3.blocks.2.attn.pool_k.weight True
# stages.3.blocks.2.attn.norm_k.weight True
# stages.3.blocks.2.attn.norm_k.bias True
# stages.3.blocks.2.attn.pool_v.weight True
# stages.3.blocks.2.attn.norm_v.weight True
# stages.3.blocks.2.attn.norm_v.bias True
# stages.3.blocks.2.norm2.weight True
# stages.3.blocks.2.norm2.bias True
# stages.3.blocks.2.mlp.fc1.weight True
# stages.3.blocks.2.mlp.fc1.bias True
# stages.3.blocks.2.mlp.fc2.weight True
# stages.3.blocks.2.mlp.fc2.bias True
# stages.3.blocks.3.norm1.weight True
# stages.3.blocks.3.norm1.bias True
# stages.3.blocks.3.attn.rel_pos_h True
# stages.3.blocks.3.attn.rel_pos_w True
# stages.3.blocks.3.attn.qkv.weight True
# stages.3.blocks.3.attn.qkv.bias True
# stages.3.blocks.3.attn.proj.weight True
# stages.3.blocks.3.attn.proj.bias True
# stages.3.blocks.3.attn.pool_q.weight True
# stages.3.blocks.3.attn.norm_q.weight True
# stages.3.blocks.3.attn.norm_q.bias True
# stages.3.blocks.3.attn.pool_k.weight True
# stages.3.blocks.3.attn.norm_k.weight True
# stages.3.blocks.3.attn.norm_k.bias True
# stages.3.blocks.3.attn.pool_v.weight True
# stages.3.blocks.3.attn.norm_v.weight True
# stages.3.blocks.3.attn.norm_v.bias True
# stages.3.blocks.3.norm2.weight True
# stages.3.blocks.3.norm2.bias True
# stages.3.blocks.3.mlp.fc1.weight True
# stages.3.blocks.3.mlp.fc1.bias True
# stages.3.blocks.3.mlp.fc2.weight True
# stages.3.blocks.3.mlp.fc2.bias True
# norm.weight True
# norm.bias True
# head.fc.weight True
# head.fc.bias True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs,save_path):
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {100 * correct / total:.2f}%")
        torch.save(model.state_dict(), f"{save_path}/model_epoch_{epoch+1}.pth") #we r saving model after every epoch 

        validate_model(model, val_loader, criterion)


def validate_model(model, val_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    print(f'Validation Loss: {val_loss/len(val_loader):.4f}, Accuracy: {100 * correct / total:.2f}%')

# %%
train_model(model, train_loader, val_loader, criterion, optimizer, epochs, save_path = "models_augmentations") 
#kindly change path
# Out:
# Epoch [1/20], Loss: 0.4140, Accuracy: 87.40%
# Validation Loss: 0.2666, Accuracy: 91.51%
# Epoch [2/20], Loss: 0.2611, Accuracy: 91.69%
# Validation Loss: 0.2754, Accuracy: 91.19%
# Epoch [3/20], Loss: 0.2144, Accuracy: 92.89%
# Validation Loss: 0.2173, Accuracy: 93.06%
# Epoch [4/20], Loss: 0.1906, Accuracy: 93.84%
# Validation Loss: 0.2192, Accuracy: 92.59%
# Epoch [5/20], Loss: 0.1696, Accuracy: 94.51%
# Validation Loss: 0.2686, Accuracy: 91.51%
# Epoch [6/20], Loss: 0.1534, Accuracy: 94.89%
# Validation Loss: 0.1959, Accuracy: 93.66%
# Epoch [7/20], Loss: 0.1399, Accuracy: 95.26%
# Validation Loss: 0.1984, Accuracy: 93.66%
# Epoch [8/20], Loss: 0.1287, Accuracy: 95.68%
# Validation Loss: 0.1863, Accuracy: 94.07%
# Epoch [9/20], Loss: 0.1183, Accuracy: 96.00%
# Validation Loss: 0.2036, Accuracy: 93.58%
# Epoch [10/20], Loss: 0.1104, Accuracy: 96.16%
# Validation Loss: 0.1845, Accuracy: 94.40%
# Epoch [11/20], Loss: 0.1010, Accuracy: 96.53%
# Validation Loss: 0.2147, Accuracy: 93.93%
# Epoch [12/20], Loss: 0.1000, Accuracy: 96.55%
# Validation Loss: 0.2082, Accuracy: 93.61%
